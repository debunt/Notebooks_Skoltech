# %%
import pandas as pd
from datetime import datetime, date, time
from collections import defaultdict
path = r"d:\Загрузки\part2.csv"
# %matplotlib notebook
df = pd.read_csv(path)
df = df.sort_values(by='starts_at')
df.reset_index(inplace=True, drop=True)
# Out:
# d:\jupyter\venv\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (1,4,5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0         department                   product_name  quantity  \
# 0     3267643           СЛАДОСТИ         250Г КАРАМЕЛЬ FL ГРУША         1
# 1      418612   МЯСО ОХЛАЖДЕННОЕ     КОРЕЙКА БАРАН.Н/К ОХЛ ХАЛ.         1
# 2     1974747  ОХЛАЖДЕННАЯ ПТИЦА  6 ШТ ЯЙЦО CЕЛЕН И ЙОД ОТБ FFF         1
# 3     2120690            ПЕКАРНЯ    120Г ВАФЕЛЬНЫЕ КОРЖИ ТОРЕРО         4
# 4     3267639           СЛАДОСТИ          250Г КАРАМЕЛЬ FL МЯТА         1
#
#                          category    package_type  not_found  store_id  stock  \
# 0                         ШОКОЛАД           ШТУКА          0        14  77.00
# 1  ОХЛАЖДЕН ЯГН/БАРАН/ОВЦА/КОЗЛЯТ        КИЛОГРАМ          0         2   2.14
# 2                            ЯЙЦА  УПАК. ПЛЕНОЧН.          0         2  11.00
# 3                  СВЕЖАЯ ВЫПЕЧКА           ШТУКА          0        12   5.00
# 4                         ШОКОЛАД           ШТУКА          0        14  78.00
#
# ...
