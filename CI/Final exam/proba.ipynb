# %%
import cv2
import matplotlib as plt

from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
from bitarray import bitarray
import binascii
import base64
from PIL import Image
from scipy.signal import convolve2d
from skimage import color, data, restoration

# %%
image = Image.open(r"D:\Jupyter\Skoltech\CI\Final exam\Capture.png")
image = np.asarray(image)
psf = np.ones((20, 20))
out = skimage.restoration.wiener(image, psf, 100)
plt.imshow(out, cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0443f50ab7dc> in <module>
#       3 image = np.asarray(image)
#       4 psf = np.ones((20, 20))
# ----> 5 out = skimage.restoration.wiener(image, psf, 100)
#       6 plt.imshow(out, cmap="gray")
#
# NameError: name 'skimage' is not defined

# %%
plt.imshow(image, cmap="gray")
