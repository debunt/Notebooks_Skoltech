# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize=(10,5))
path = r"/Users/debunt/Work_Learning/Yandex.Disk.localized/SKOLTECH/Courses/perception_course/PS/ps3/ps3_code/chi_sqaured.txt"


chi_squared = np.genfromtxt(path)
plt.xlabel("t")
plt.ylabel("~$\chi^2$")
plt.plot(chi_squared)
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
fig = plt.figure(figsize=(10,5))
path = r"/Users/debunt/Work_Learning/Yandex.Disk.localized/SKOLTECH/Courses/perception_course/PS/ps3/ps3_code/chi_sqaured.txt"


chi_squared = np.genfromtxt(path)
plt.plot(chi_squared)
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">
