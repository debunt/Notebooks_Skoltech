# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches # for manual legend
# %matplotlib notebook
import pickle

# %%
def load_obj(name ):
    """
    Load numpy array in pickle format
    :param name:
    :return:
    """
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
pathPoses = r"/Users/debunt/Work_Learning/programming/Robotics_Project_3DMap/Velodyne3DMap/Velodyne_3Dmap/data/2020-03-13-20-13-09/results/3DPoses"
poses = load_obj(pathPoses)
fig = plt.figure(1)
path = r"/Users/debunt/Work_Learning/programming/Robotics_Project_3DMap/Velodyne3DMap/Velodyne_3Dmap/data/2020-03-13-20-13-09/results/ICP_PCD - Cloud_cleaned.txt"
pcd = np.genfromtxt(path, delimiter=" ")
plt.scatter(pcd[:,0], pcd[:,1], s=2, c="r")
plt.title("3D Map")
plt.ylabel("Y, [m]")
plt.xlabel("X, [m]")
path = r"/Users/debunt/Work_Learning/programming/Robotics_Project_3DMap/Velodyne3DMap/Velodyne_3Dmap/data/2020-03-13-20-13-09/results/pose_graph/2020-03-13-20-13-09_rectified2_posegraph_asci - Cloud_cleaned.txt"
pcd = np.genfromtxt(path, delimiter=" ")
plt.scatter(pcd[:,0], pcd[:,1], s=1, c="g", alpha=0.1)
plt.scatter(poses[:,0,3], poses[:,1,3], s=2, c="black")
    

plt.legend(handles=[mpatches.Patch(color='green', label='Pose graph PCD'),
                    mpatches.Patch(color='red', label='ICP PCD'), 
                    mpatches.Patch(color='black', label='Trajectory')])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
import open3d
import os


path = r"/Users/debunt/Work_Learning/programming/Robotics_Project_3DMap/Velodyne3DMap/Velodyne_3Dmap/data/2020-03-13-20-13-09/results/pose_graph/2020-03-13-20-13-09_rectified2_posegraph.pcd"
pcd = open3d.io.read_point_cloud(path, format="pcd")
path = os.path.join(os.path.dirname(path), (os.path.basename(path).split(".")[0] + "_asci" + ".pcd"))
open3d.io.write_point_cloud(path, pcd, write_ascii=True)
# Out:
# True
