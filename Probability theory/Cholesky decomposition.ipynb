# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.linalg import cholesky
import numpy as np
Sigma = np.array([[4,-2], [-2,10]])
L = cholesky(Sigma, lower=True)
L
# Out:
# array([[ 2.,  0.],
#        [-1.,  3.]])
