# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.stats import binom
import numpy as np
x = np.linspace(-1, 3, 100)
y = np.linspace(-1, 3, 100)
X, Y = np.meshgrid(x, y)
X
# Out:
# array([[-1.        , -0.95959596, -0.91919192, ...,  2.91919192,
#          2.95959596,  3.        ],
#        [-1.        , -0.95959596, -0.91919192, ...,  2.91919192,
#          2.95959596,  3.        ],
#        [-1.        , -0.95959596, -0.91919192, ...,  2.91919192,
#          2.95959596,  3.        ],
#        ...,
#        [-1.        , -0.95959596, -0.91919192, ...,  2.91919192,
#          2.95959596,  3.        ],
#        [-1.        , -0.95959596, -0.91919192, ...,  2.91919192,
#          2.95959596,  3.        ],
#        [-1.        , -0.95959596, -0.91919192, ...,  2.91919192,
#          2.95959596,  3.        ]])
